# %%
#          Olivier Grisel <olivier.grisel@ensta.org>
#          Mathieu Blondel <mathieu@mblondel.org>
#          Gael Varoquaux
# License: BSD 3 clause (C) INRIA 2011

from time import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection, neighbors)
print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# ### SMOTE Data

# %%
Data = pd.read_csv('../../Data/SMOTE/SMOTE.csv')
X = Data.iloc[:,:-1]
y = Data.iloc[:,-1]
print(y)
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 504289    1
# 504290    1
# 504291    1
# 504292    1
# 504293    1
# Name: FraudFound, Length: 504294, dtype: int64

# %%
print(X.shape,y.shape)
# Out:
# (504294, 98) (504294,)

# %%
# ----------------------------------------------------------------------
# PCA embedding of the digits dataset
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents, columns = ['pc 1', 'pc 2'])

# %% [markdown]
# ### Visualize 2D Projection (when n_components=2)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [0,1]
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['FraudFound'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'pc 1']
               , finalDf.loc[indicesToKeep, 'pc 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.19115108, 0.15184825])

# %%
pca = PCA().fit(X)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.19115108, 0.34299933, 0.44015467, 0.53184892, 0.60199799,
#        0.65983892, 0.69820256, 0.7208217 , 0.73985521, 0.75617456,
#        0.76972079, 0.78219605, 0.79378313, 0.80471025, 0.81553157,
#        0.82580458, 0.83578149, 0.84549554, 0.85500439, 0.8638875 ,
#        0.87235359, 0.88047024, 0.88830128, 0.89563993, 0.90286182,
#        0.90947746, 0.91593467, 0.9222583 , 0.92812887, 0.93363204,
#        0.93907257, 0.94447164, 0.94970554, 0.95449064, 0.95914629,
#        0.96366627, 0.9680399 , 0.97232763, 0.97640584, 0.98034032,
#        0.98371949, 0.98692188, 0.9894983 , 0.99180947, 0.99343401,
#        0.99488049, 0.99588335, 0.99658858, 0.99725501, 0.99781097,
#        0.99833094, 0.99865847, 0.99896401, 0.99922938, 0.99948274,
#        0.99968549, 0.99977438, 0.99981814, 0.99986092, 0.99990065,
#        0.99993697, 0.99995645, 0.99997244, 0.99998444, 0.99999029,
#        0.99999375, 0.99999611, 0.9999977 , 0.99999843, 0.99999895,
# ...

# %% [markdown]
# ### n_components=45 captures 99% of the variance

# %%
# ----------------------------------------------------------------------
# PCA embedding of the digits dataset
from sklearn.decomposition import PCA
pca = PCA(n_components=40)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents)

# %%
SMOTE_PCA = principalDf
SMOTE_PCA['FraudFound'] = y

# %%
# Save the file
SMOTE_PCA.to_csv(r"./EmbeddedData/SMOTE_PCA.csv", index=False)

# %% [markdown]
# ### TGAN Data

# %%
Data = pd.read_csv('../../Data/TGAN/TGAN.csv')
X = Data.iloc[:,:-1]
y = Data.iloc[:,-1]
print(y)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 504235    0
# 504236    0
# 504237    0
# 504238    0
# 504239    0
# Name: FraudFound, Length: 504240, dtype: int64

# %%
# ----------------------------------------------------------------------
# PCA embedding of the digits dataset
from sklearn.decomposition import PCA
pca = PCA(n_components=40)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents)

# %%
TGAN_PCA = principalDf
TGAN_PCA['FraudFound'] = y

# %%
# Save the file
TGAN_PCA.to_csv(r"./EmbeddedData/TGAN_PCA.csv", index=False)

# %% [markdown]
# ### ADASYN Data

# %%
Data = pd.read_csv('../../Data/ADASYN/ADASYN.csv')
X = Data.iloc[:,:-1]
y = Data.iloc[:,-1]
print(y)
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 505855    1
# 505856    1
# 505857    1
# 505858    1
# 505859    1
# Name: FraudFound, Length: 505860, dtype: int64

# %%
# ----------------------------------------------------------------------
# PCA embedding of the digits dataset
from sklearn.decomposition import PCA
pca = PCA(n_components=40)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents)

# %%
ADASYN_PCA = principalDf
ADASYN_PCA['FraudFound'] = y

# %%
# Save the file
ADASYN_PCA.to_csv(r"./EmbeddedData/ADASYN_PCA.csv", index=False)

# %% [markdown]
# ### Test Data

# %%
Data = pd.read_csv('../../Data/test.csv')
X = Data.iloc[:,:-1]
y = Data.iloc[:,-1]
print(y)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 95642    0
# 95643    1
# 95644    0
# 95645    0
# 95646    0
# Name: FraudFound, Length: 95647, dtype: int64

# %%
# ----------------------------------------------------------------------
# PCA embedding of the digits dataset
from sklearn.decomposition import PCA
pca = PCA(n_components=40)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents)

# %%
test_PCA = principalDf
test_PCA['FraudFound'] = y

# %%
# Save the file
test_PCA.to_csv(r"./EmbeddedData/test_PCA.csv", index=False)

# %% [markdown]
# ### Train Data

# %%
Data = pd.read_csv('../../Data/train.csv')
X = Data.iloc[:,:-1]
y = Data.iloc[:,-1]
print(y)
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 286935    0
# 286936    0
# 286937    0
# 286938    0
# 286939    0
# Name: FraudFound, Length: 286940, dtype: int64

# %%
# ----------------------------------------------------------------------
# PCA embedding of the digits dataset
from sklearn.decomposition import PCA
pca = PCA(n_components=40)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents)

# %%
train_PCA = principalDf
train_PCA['FraudFound'] = y

# %%
# Save the file
train_PCA.to_csv(r"./EmbeddedData/train_PCA.csv", index=False)
