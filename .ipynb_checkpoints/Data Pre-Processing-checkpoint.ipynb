# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os

# %%
df = pd.read_csv("./Data/PythonData.csv")
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (34) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (382587, 62)

# %% [markdown]
# ### Replace -NA- values with NULL

# %%
df=df.replace('-NA-',np.NaN)

# %%
dates_features = ['Treatment Start Date', 'Treatment End Date', 'Claim Settlement Date', 'Claim Reported Date',
                  'Claim Paid Date', 'Policy Commencement Date', 'Policy Effective Date', 'Policy Termination Date',
                  'Birth Date ', 'Insured Original Commencement Date', 'Insured Effective Date', 'Insured Termination Date']

# %% [markdown]
# ### Converting to date format

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382587 entries, 0 to 382586
# Data columns (total 62 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Policy Number                       382587 non-null  object
#  1   Insured Id                          382587 non-null  object
#  2   Claim Identification Number         382587 non-null  object
#  3   Benefit Type                        382587 non-null  object
#  4   Claim Status                        382587 non-null  object
#  5   Treatment Start Date                382587 non-null  object
#  6   Treatment End Date                  352333 non-null  object
#  7   Claim Settlement Date               341601 non-null  object
#  8   Claim Reported Date                 350646 non-null  object
#  9   Claim Billed Amount                 382587 non-null  int64
#  10  Approved / Allowed Amount           382587 non-null  int64
#  11  Payment Denial Reason               16205 non-null   object
#  12  Claim Paid Amount                   325035 non-null  object
#  13  ClaimEvent_TPA_ID                   382587 non-null  int64
#  14  Payment Tariff*                     381153 non-null  float64
#  15  Medical Service Provider ID         382587 non-null  object
#  16  Medical Service Provider Name       382587 non-null  object
#  17  Medical Service Provider Type       382587 non-null  object
#  18  Medical Service Provider Country    382587 non-null  object
#  19  Doctor Code                         0 non-null       float64
#  20  Room Type                           382587 non-null  object
#  21  No of Days Stayed                   352333 non-null  float64
#  22  Mapped_Diagnosis_Code               0 non-null       float64
#  23  Mapped_Diagnosis_Name               0 non-null       float64
#  24  Primary Diagnosis Code              382587 non-null  object
#  25  Primary Diagnosis Name              381813 non-null  object
#  26  Primary Procedure Code              381811 non-null  object
#  27  Primary Procedure Name              381816 non-null  object
#  28  Secondary Diagnosis Code            0 non-null       float64
#  29  Secondary Diagnosis Name            0 non-null       float64
#  30  Secondary Procedure Code            0 non-null       float64
#  31  Secondary Procedure Name            0 non-null       float64
#  32  Aspirational district               35518 non-null   object
#  33  Hospital Type                       382587 non-null  object
#  34  Category                            16 non-null      object
#  35  Type of Public Hospital             155451 non-null  object
#  36  PG / DNB Teaching hospital          22471 non-null   object
#  37  TPA NAME                            382587 non-null  object
#  38  Net Amt                             382587 non-null  int64
#  39  Claim Paid Date                     327044 non-null  object
#  40  Policy Number.1                     382587 non-null  object
#  41  Benefit Code                        382587 non-null  object
#  42  Policy Commencement Date            382587 non-null  object
#  43  Policy Effective Date               382587 non-null  object
#  44  Policy Termination Date             382587 non-null  object
#  45  Annual Client Premium Amount        382587 non-null  object
#  46  Premium Payment Frequency Code      0 non-null       float64
#  47  Plan Codes                          0 non-null       float64
#  48  Birth Date                          382587 non-null  int64
#  49  Gender Code                         382587 non-null  object
#  50  Insured Original Commencement Date  382587 non-null  object
#  51  Insured Effective Date              382587 non-null  object
#  52  Insured Termination Date            382587 non-null  object
#  53  Insured Id.1                        382587 non-null  object
#  54  Relationship Code                   0 non-null       float64
#  55  Residence Location                  382587 non-null  object
#  56  Reject status more than 3 months    382587 non-null  int64
#  57  diff                                382587 non-null  object
#  58  reclaimed?                          382587 non-null  int64
#  59  trigger                             9141 non-null    float64
#  60  cancelled                           382587 non-null  int64
#  61  Fraud                               382587 non-null  int64
# dtypes: float64(13), int64(9), object(40)
# memory usage: 181.0+ MB

# %%
for dates in dates_features:
    df[dates]=pd.to_datetime(df[dates])

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df.sort_values('percent_missing', inplace=True)

# %%
missing_value_df.tail(20)
# Out:
#                                                    column_name  \
# Claim Reported Date                        Claim Reported Date
# Claim Settlement Date                    Claim Settlement Date
# Claim Paid Date                                Claim Paid Date
# Claim Paid Amount                            Claim Paid Amount
# Type of Public Hospital                Type of Public Hospital
# Aspirational district                    Aspirational district
# PG / DNB Teaching hospital          PG / DNB Teaching hospital
# Payment Denial Reason                    Payment Denial Reason
# trigger                                                trigger
# Category                                              Category
# Relationship Code                            Relationship Code
# Mapped_Diagnosis_Name                    Mapped_Diagnosis_Name
# Premium Payment Frequency Code  Premium Payment Frequency Code
# Mapped_Diagnosis_Code                    Mapped_Diagnosis_Code
# Doctor Code                                        Doctor Code
# Secondary Procedure Name              Secondary Procedure Name
# Secondary Diagnosis Name              Secondary Diagnosis Name
# Secondary Diagnosis Code              Secondary Diagnosis Code
# Plan Codes                                          Plan Codes
# Secondary Procedure Code              Secondary Procedure Code
#
#                                 percent_missing
# Claim Reported Date                    8.348689
# Claim Settlement Date                 10.712857
# Claim Paid Date                       14.517744
# Claim Paid Amount                     15.042853
# Type of Public Hospital               59.368457
# Aspirational district                 90.716360
# PG / DNB Teaching hospital            94.126565
# Payment Denial Reason                 95.764362
# trigger                               97.610740
# Category                              99.995818
# Relationship Code                    100.000000
# Mapped_Diagnosis_Name                100.000000
# Premium Payment Frequency Code       100.000000
# Mapped_Diagnosis_Code                100.000000
# Doctor Code                          100.000000
# Secondary Procedure Name             100.000000
# Secondary Diagnosis Name             100.000000
# Secondary Diagnosis Code             100.000000
# Plan Codes                           100.000000
# Secondary Procedure Code             100.000000

# %%
# to check the missing value
sns.heatmap(df.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Removing features with many missing values

# %%
remove_features = ['Claim Identification Number', 'Policy Number', 'Insured Id', 'Aspirational district', 'Medical Service Provider Name', 'Medical Service Provider Country',
                   'PG / DNB Teaching hospital', 'Primary Diagnosis Name', 'Primary Procedure Name', 'Payment Denial Reason',
                   'trigger', 'Category', 'Policy Number.1', 'Insured Id.1', 'diff', 'reclaimed?', 'cancelled',
                   'Relationship Code', 'Mapped_Diagnosis_Name', 'Premium Payment Frequency Code', 'Mapped_Diagnosis_Code',
                   'Doctor Code', 'Secondary Procedure Name', 'Secondary Diagnosis Name', 'Secondary Diagnosis Code',
                   'Plan Codes', 'Secondary Procedure Code']

# %%
# Cleaned dataset
cleaned_df = df.drop(remove_features, axis=1)

# %%
data_description = pd.DataFrame()

# %%
data_description=pd.DataFrame(cleaned_df.columns)

# %%
data_description
# Out:
#                                      0
# 0                         Benefit Type
# 1                         Claim Status
# 2                 Treatment Start Date
# 3                   Treatment End Date
# 4                Claim Settlement Date
# 5                  Claim Reported Date
# 6                  Claim Billed Amount
# 7            Approved / Allowed Amount
# 8                    Claim Paid Amount
# 9                    ClaimEvent_TPA_ID
# 10                     Payment Tariff*
# 11         Medical Service Provider ID
# 12       Medical Service Provider Type
# 13                           Room Type
# 14                   No of Days Stayed
# 15              Primary Diagnosis Code
# 16              Primary Procedure Code
# 17                       Hospital Type
# 18             Type of Public Hospital
# 19                            TPA NAME
# 20                             Net Amt
# 21                     Claim Paid Date
# 22                        Benefit Code
# 23            Policy Commencement Date
# 24               Policy Effective Date
# 25             Policy Termination Date
# 26        Annual Client Premium Amount
# 27                         Birth Date
# 28                         Gender Code
# 29  Insured Original Commencement Date
# 30              Insured Effective Date
# 31            Insured Termination Date
# 32                  Residence Location
# 33    Reject status more than 3 months
# 34                               Fraud

# %%
data_description.to_csv(r"./Data/data_description.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-76518d70fa37> in <module>
# ----> 1 data_description.to_csv(r"./Data/data_description.csv", index=False)
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
cleaned_df['Claim Paid Amount']=pd.to_numeric(cleaned_df['Claim Paid Amount'], errors='coerce')

# %%
sns.heatmap(cleaned_df.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
for features in cleaned_df.select_dtypes(include = 'object').columns:
    print(features, ":", cleaned_df[features].unique())
# Out:
# Benefit Type : ['SURGICAL' 'MEDICAL']
# Claim Status : ['Paid' 'Cancelled / Rejected' 'Outstanding' 'Pre-Auth Approved']
# Medical Service Provider ID : ['HOSP3G91629' 'HOSP3G59002' 'HOSP3G81429' 'HOSP3G82225' 'HOSP3G92566'
#  'HOSP3G81922' 'HOSP3G58357' 'HOSP3G81425' 'HOSP3P11538' 'HOSP3G81396'
#  'HOSP3P53909' 'HOSP3G80786' 'HOSP3P91871' 'HOSP3G83301' 'HOSP3G99957'
#  'HOSP3G58889' 'HOSP3G59094' 'HOSP3G81037' 'HOSP3G84341' 'HOSP3G80815'
#  'HOSP37G26966' 'HOSP3P11504' 'HOSP3P15999' 'HOSP3G81950' 'HOSP3P58295'
#  'HOSP3G61862' 'HOSP3G82867' 'HOSP3G82001' 'HOSP4G15575' 'HOSP3G84209'
#  'HOSP3P68104' 'HOSP3P57234' 'HOSP3P21150' 'HOSP3P28996' 'HOSP3G62650'
#  'HOSP3G100093' 'HOSP3G59614' 'HOSP3P49877' 'HOSP3G81952' 'HOSP3P71432'
#  'HOSP3G81176' 'HOSP3P62840' 'HOSP3P10675' 'HOSP3P25897' 'HOSP3G81939'
#  'HOSP3P57665' 'HOSP3G81096' 'HOSP3P23204' 'HOSP3P14339' 'HOSP3P59413'
#  'HOSP3G61363' 'HOSP3G80804' 'HOSP3P102602' 'HOSP3G81986' 'HOSP3G80774'
#  'HOSP3P68582' 'HOSP3G81094' 'HOSP3G81642' 'HOSP3P22560' 'HOSP3G93109'
#  'HOSP3G81062' 'HOSP3G84584' 'HOSP3P12267' 'HOSP3P89903' 'HOSP3P63305'
#  'HOSP3P13790' 'HOSP3P16686' 'HOSP3G81997' 'HOSP3P58002' 'HOSP3G81685'
#  'HOSP3P25606' 'HOSP3G84572' 'HOSP3P100609' 'HOSP3G81699' 'HOSP3P16665'
#  'HOSP3G60198' 'HOSP3G58366' 'HOSP3P11108' 'HOSP3P89941' 'HOSP3G81141'
#  'HOSP3P10731' 'HOSP3P21135' 'HOSP3P13265' 'HOSP3P11084' 'HOSP3P71794'
#  'HOSP3P58722' 'HOSP3P98542' 'HOSP3P12536' 'HOSP3P11828' 'HOSP3G81054'
#  'HOSP3P58556' 'HOSP3G81895' 'HOSP3P89205' 'HOSP3G81586' 'HOSP3P31431'
#  'HOSP3G82905' 'HOSP3G81606' 'HOSP3P60761' 'HOSP3G81458' 'HOSP3P57139'
#  'HOSP3P62634' 'HOSP3P14817' 'HOSP3P92088' 'HOSP3P70073' 'HOSP3P65443'
#  'HOSP3P68727' 'HOSP3G98484' 'HOSP3G80765' 'HOSP3G81345' 'HOSP3P20731'
#  'HOSP3P52841' 'HOSP3P54306' 'HOSP3G85223' 'HOSP3P10867' 'HOSP3G81849'
#  'HOSP3P25377' 'HOSP3P37440' 'HOSP3P58289' 'HOSP3P73510' 'HOSP3P66289'
#  'HOSP3P91932' 'HOSP3P15374' 'HOSP3P89888' 'HOSP3P32581' 'HOSP3G81110'
#  'HOSP3P61412' 'HOSP3P57777' 'HOSP3P15615' 'HOSP3P98975' 'HOSP3P106455'
#  'HOSP3P27593' 'HOSP3P70163' 'HOSP3G81130' 'HOSP3G84626' 'HOSP3P36957'
#  'HOSP3P93997' 'HOSP3P63055' 'HOSP3G81353' 'HOSP3G81976' 'HOSP3P98841'
#  'HOSP3P25184' 'HOSP3P92207' 'HOSP3P100531' 'HOSP3G90204' 'HOSP3G81908'
#  'HOSP3P66980' 'HOSP3G61100' 'HOSP3G81433' 'HOSP3P23154' 'HOSP3G99195'
#  'HOSP3G81150' 'HOSP3P59631' 'HOSP3P50519' 'HOSP3G78642' 'HOSP3G81120'
#  'HOSP3G81906' 'HOSP3P91089' 'HOSP3G81598' 'HOSP3G81180' 'HOSP3G58364'
#  'HOSP3G81369' 'HOSP3G58882' 'HOSP3P89415' 'HOSP3P66049' 'HOSP3P12798'
#  'HOSP3P19632' 'HOSP3P62546' 'HOSP3P93201' 'HOSP3P69756' 'HOSP3G88867'
#  'HOSP3P58829' 'HOSP3P56191' 'HOSP3P89895' 'HOSP3P70154' 'HOSP3P71424'
#  'HOSP3G86505' 'HOSP3P34001' 'HOSP3P57751' 'HOSP3G85691' 'HOSP3P13791'
#  'HOSP3P21239' 'HOSP3P60563' 'HOSP3P58422' 'HOSP3P12041' 'HOSP3P19707'
#  'HOSP3P19700' 'HOSP3P93614' 'HOSP3G63048' 'HOSP3G80779' 'HOSP3P89959'
#  'HOSP3P99164' 'HOSP3G84574' 'HOSP3G81158' 'HOSP3G77043' 'HOSP3P61881'
#  'HOSP3G81632' 'HOSP3P69760' 'HOSP3P100035' 'HOSP3P38200' 'HOSP3P63299'
#  'HOSP3P92120' 'HOSP3P16183' 'HOSP3G81059' 'HOSP3P98811' 'HOSP3P102822'
#  'HOSP3P11450' 'HOSP3P23124' 'HOSP3G81360' 'HOSP3P89406' 'HOSP3G91686'
#  'HOSP3G58245' 'HOSP3G58377' 'HOSP3G58475' 'HOSP3G81376' 'HOSP3P25404'
#  'HOSP3P16365' 'HOSP3G91709' 'HOSP3G90904' 'HOSP3P22961' 'HOSP3G81644'
#  'HOSP3P24067' 'HOSP3P58568' 'HOSP3P30412' 'HOSP3P81352' 'HOSP3G81040'
#  'HOSP3G81070' 'HOSP3G81078' 'HOSP3G80800' 'HOSP3P63429' 'HOSP3G81672'
#  'HOSP3G81134' 'HOSP3G80773' 'HOSP3G81679' 'HOSP3P59028' 'HOSP3P111573'
#  'HOSP3G82019' 'HOSP3G80824' 'HOSP3G81619' 'HOSP3P102615' 'HOSP3P70074'
#  'HOSP3G62462' 'HOSP3G89881' 'HOSP3G81961' 'HOSP3G89889' 'HOSP3P99900'
#  'HOSP3G81637' 'HOSP3P65603' 'HOSP3G81367' 'HOSP3G81924' 'HOSP3G91678'
#  'HOSP3P22830' 'HOSP3P11274' 'HOSP3G60508' 'HOSP3P74532' 'HOSP3G81097'
#  'HOSP3P65756' 'HOSP3G81413' 'HOSP3P70449' 'HOSP3G81942' 'HOSP3P103041'
#  'HOSP3G84598' 'HOSP3G63378' 'HOSP3P16302' 'HOSP3P59194' 'HOSP3G73378'
#  'HOSP3P57316' 'HOSP3P58486' 'HOSP3G98957' 'HOSP3G83067' 'HOSP3P53030'
#  'HOSP3G81649' 'HOSP3G80838' 'HOSP3G81690' 'HOSP3G58215' 'HOSP3P11665'
#  'HOSP3G74692' 'HOSP3P57094' 'HOSP3G85209' 'HOSP3P23149' 'HOSP3P25397'
#  'HOSP3P10674' 'HOSP3G81636' 'HOSP3P62736' 'HOSP3P10941' 'HOSP3P32871'
#  'HOSP3G83458' 'HOSP3P52368' 'HOSP3P102190' 'HOSP3P58222' 'HOSP3P43363'
#  'HOSP3P89898' 'HOSP3P10931' 'HOSP3G81090' 'HOSP6P01175' 'HOSP3G81061'
#  'HOSP3G81119' 'HOSP3G81085' 'HOSP3P106633' 'HOSP3P91173' 'HOSP3G91723'
#  'HOSP3P67729' 'HOSP3P48986' 'HOSP3P19873' 'HOSP3P62601' 'HOSP3P16493'
#  'HOSP3G81609' 'HOSP3P51816' 'HOSP3P11844' 'HOSP3G81350' 'HOSP3G100273'
#  'HOSP3G81941' 'HOSP3P12139' 'HOSP3G107097' 'HOSP3P37094' 'HOSP3G80780'
#  'HOSP3G81058' 'HOSP3P15544' 'HOSP3P36649' 'HOSP3G62418' 'HOSP3G62421'
#  'HOSP3P59683' 'HOSP3G81669' 'HOSP3G81931' 'HOSP3P26108' 'HOSP3G78848'
#  'HOSP3P34245' 'HOSP3P29987' 'HOSP3G81984' 'HOSP3G83264' 'HOSP3G58371'
#  'HOSP3P51801' 'HOSP3G81416' 'HOSP3P63332' 'HOSP3P70927' 'HOSP6P01558'
#  'HOSP3G81129' 'HOSP3P18661' 'HOSP3P101302' 'HOSP3P58849' 'HOSP3P90752'
#  'HOSP3G81894' 'HOSP3G82195' 'HOSP3G58365' 'HOSP3P85673' 'HOSP3P11092'
#  'HOSP3P85280' 'HOSP3P63880' 'HOSP3G82866' 'HOSP3P19597' 'HOSP3P91583'
#  'HOSP3P34433' 'HOSP3G81958' 'HOSP3P11877' 'HOSP3P41653' 'HOSP3P68803'
#  'HOSP3P72345' 'HOSP3P60261' 'HOSP3P13813' 'HOSP3P61660' 'HOSP3P10926'
#  'HOSP3P50173' 'HOSP3G61164' 'HOSP3G82002' 'HOSP3P85453' 'HOSP3P59586'
#  'HOSP3G99794' 'HOSP3P37308' 'HOSP3P60565' 'HOSP3G81994' 'HOSP3G81092'
#  'HOSP6P01945' 'HOSP3G62599' 'HOSP3P93605' 'HOSP3P57220' 'HOSP3P90917'
#  'HOSP3P14357' 'HOSP3G81391' 'HOSP3G81683' 'HOSP4P62024' 'HOSP4G03896'
#  'HOSP3P11484' 'HOSP3P21606' 'HOSP3G81660' 'HOSP3P39371' 'HOSP3G91688'
#  'HOSP3G88411' 'HOSP3G81064' 'HOSP3G91564' 'HOSP3P11982' 'HOSP3G91691'
#  'HOSP3P29128' 'HOSP3P59050' 'HOSP3P37939' 'HOSP3P11105' 'HOSP3P91735'
#  'HOSP3P57602' 'HOSP3G91626' 'HOSP3G58356' 'HOSP3P81794' 'HOSP3P11387'
#  'HOSP3P58209' 'HOSP3P100707' 'HOSP3P100834' 'HOSP3P92697' 'HOSP3P27540'
#  'HOSP3P58777' 'HOSP3P28713' 'HOSP3P69789' 'HOSP3P70103' 'HOSP3P26340'
#  'HOSP3P13748' 'HOSP3G81178' 'HOSP3P20997' 'HOSP3P58268' 'HOSP3P101114'
#  'HOSP3P57667' 'HOSP3P60234' 'HOSP3P49016' 'HOSP4P81206' 'HOSP3G91710'
#  'HOSP3P100284' 'HOSP3P78495' 'HOSP3P44541' 'HOSP3P11377' 'HOSP3P37874'
#  'HOSP3P113832' 'HOSP4P04814' 'HOSP3P16060' 'HOSP3G82010' 'HOSP3P60227'
#  'HOSP3P101167' 'HOSP3P21127' 'HOSP3P100611' 'HOSP3P73589' 'HOSP3P102425'
#  'HOSP3P34643' 'HOSP3P11001' 'HOSP6G03704' 'HOSP3G82654' 'HOSP3P56551'
#  'HOSP3P98739' 'HOSP3G81946' 'HOSP3P63281' 'HOSP3P111578' 'HOSP3P111036'
#  'HOSP3P66542' 'HOSP3P24411' 'HOSP3G81617' 'HOSP3P110976' 'HOSP3P23214'
#  'HOSP3P100997' 'HOSP3P50316' 'HOSP3P21928' 'HOSP3P102242' 'HOSP3P10932'
#  'HOSP3P91585' 'HOSP3P58639' 'HOSP3P101054' 'HOSP3P111544' 'HOSP3P34957'
#  'HOSP3P20747' 'HOSP3P23321' 'HOSP3P10934' 'HOSP3P42898' 'HOSP3P19656'
#  'HOSP3G81707' 'HOSP3G108546' 'HOSP3P27677' 'HOSP3P51656' 'HOSP3G110981'
#  'HOSP3P13343' 'HOSP3P50507' 'HOSP3G98509' 'HOSP3G81105' 'HOSP3P59662'
#  'HOSP3P84011' 'HOSP3P59930' 'HOSP3P92625' 'HOSP3P98839' 'HOSP3P65870'
#  'HOSP3P58279' 'HOSP6P02251' 'HOSP3P21232' 'HOSP3P70087' 'HOSP3P27412'
#  'HOSP3P46490' 'HOSP3P22347' 'HOSP3P86179' 'HOSP3P100854' 'HOSP3G102321'
#  'HOSP3P101287' 'HOSP3P36398' 'HOSP3P82682' 'HOSP3P113382' 'HOSP3P91673'
#  'HOSP3P107658' 'HOSP3P65872' 'HOSP3G81086' 'HOSP3G81124' 'HOSP3P101350'
#  'HOSP37G36989' 'HOSP3G83078' 'HOSP3P50725' 'HOSP6P98291' 'HOSP3G82024'
#  'HOSP3P83652' 'HOSP4G12390' 'HOSP3P23004' 'HOSP3P12074' 'HOSP3P16177'
#  'HOSP3P10737' 'HOSP3P57208' 'HOSP4P91096' 'HOSP3P62852' 'HOSP3P100485'
#  'HOSP3P102483' 'HOSP3G60105' 'HOSP3G58990' 'HOSP3P59889' 'HOSP3P47862'
#  'HOSP3P83166' 'HOSP3P90933' 'HOSP3P91921' 'HOSP3P68259' 'HOSP3G80862'
#  'HOSP3G60007' 'HOSP3P23501' 'HOSP3G81126' 'HOSP3G81956' 'HOSP3G81144'
#  'HOSP3G90126' 'HOSP3P40661' 'HOSP3P23392' 'HOSP3G91599' 'HOSP3P111247'
#  'HOSP3P46552' 'HOSP3P103100' 'HOSP3P60163' 'HOSP3P57133' 'HOSP3P11241'
#  'HOSP3P93572' 'HOSP3P34388' 'HOSP3P86790' 'HOSP3G81056' 'HOSP3P102667'
#  'HOSP3G81137' 'HOSP3P24138' 'HOSP4P03549' 'HOSP3P72312' 'HOSP3P62720'
#  'HOSP3P93295' 'HOSP3P102568' 'HOSP3P88439' 'HOSP3P12199' 'HOSP3P59485'
#  'HOSP3G81959' 'HOSP3P62730' 'HOSP3P81402' 'HOSP3P68963' 'HOSP3P61911'
#  'HOSP3P58515' 'HOSP3P48163' 'HOSP3G108371' 'HOSP3P111110' 'HOSP2P36382'
#  'HOSP3P101018' 'HOSP3P23106' 'HOSP3P93446' 'HOSP3P101064' 'HOSP3G80819'
#  'HOSP3P61214' 'HOSP3P91158' 'HOSP3P21345' 'HOSP3P117383' 'HOSP3P61691'
#  'HOSP6G03078' 'HOSP3P101005' 'HOSP3P81853' 'HOSP3P11535' 'HOSP3P92559'
#  'HOSP27P79085' 'HOSP3P90355' 'HOSP3P91023' 'HOSP3P52198' 'HOSP3P60005'
#  'HOSP3P23162' 'HOSP3P89146' 'HOSP3P10943' 'HOSP3P41116' 'HOSP3G113581'
#  'HOSP3P91483' 'HOSP3P91248' 'HOSP6G03077' 'HOSP3P13794' 'HOSP3P38106'
#  'HOSP3P89499' 'HOSP3P60222' 'HOSP3P41475' 'HOSP3P78786' 'HOSP3P106329'
#  'HOSP3P12330' 'HOSP3P92246' 'HOSP3P99146' 'HOSP3P11702' 'HOSP3P43077'
#  'HOSP3P56458' 'HOSP3P57856' 'HOSP3P10697' 'HOSP3P98324' 'HOSP3G58220'
#  'HOSP3P12304' 'HOSP3P21005' 'HOSP3P13707' 'HOSP3P58199' 'HOSP3P93065'
#  'HOSP4G13746' 'HOSP3P11807' 'HOSP3P11361' 'HOSP6P05568' 'HOSP3P27055'
#  'HOSP3P98523' 'HOSP3P104181' 'HOSP3P38356' 'HOSP3P107465' 'HOSP3P102003'
#  'HOSP3P61114' 'HOSP3P103147' 'HOSP3P84050' 'HOSP3P113022' 'HOSP3P67589'
#  'HOSP3P102519' 'HOSP3P60528' 'HOSP3P90638' 'HOSP3P24079' 'HOSP23P01386'
#  'HOSP3P98838' 'HOSP3P89977' 'HOSP3P90935' 'HOSP3P99374' 'HS02002070P'
#  'HOSP6P01453' 'HOSP3P111714' 'HOSP3P57787' 'HOSP3P65538' 'HOSP5G07688'
#  'HOSP3P42945' 'HOSP3P90278' 'HOSP6G03026' 'HOSP3P12846' 'HOSP3P90522'
#  'HOSP3G83255' 'HOSP27P79289' 'HOSP3P62109' 'HOSP6P02148' 'HOSP3P99055'
#  'HOSP23P78856' 'HOSP6P01428' 'HOSP3P35652' 'HOSP6P01584' 'HOSP1G22894'
#  'HOSP3P44812' 'HOSP3P23988' 'HOSP3P92621' 'HOSP3P15671' 'HOSP3P22294'
#  'HOSP3P106258' 'HOSP6P00642' 'HOSP3P100873' 'HOSP3P91301' 'HOSP3P22987'
#  'HOSP3P65844' 'HOSP3P100807' 'HOSP3P11652' 'HOSP9P02385' 'HOSP3P108630'
#  'HOSP3P95437' 'HOSP3P106341' 'HOSP3P60610' 'HOSP6P31021' 'HOSP3P32843'
#  'HOSP3P24169' 'HOSP3P101103' 'HOSP3P108307' 'HS02002048P' 'HOSP37G36554'
#  'HOSP3P41104' 'HOSP4P89965' 'HOSP6P00618' 'HOSP3P46255' 'HOSP6P02346'
#  'HOSP3P39259' 'HOSP3P92416' 'HOSP6P02014' 'HOSP3P111577' 'HOSP3P15270'
#  'HOSP2P89570' 'HOSP3P101319' 'HOSP4P15654' 'HOSP4G14359' 'HOSP6P03100'
#  'HOSP3P57633' 'HOSP3P15399' 'HOSP3P102900' 'HOSP6G03056' 'HOSP3P108941'
#  'HOSP3P10680' 'HOSP6P02104' 'HOSP6P02402' 'HOSP6P02165' 'HOSP3P11923'
#  'HOSP3G106260' 'HOSP6P01989' 'HS02009034P' 'HOSP37G31478' 'HOSP3P88864'
#  'HOSP3P60092' 'HOSP3P66606' 'HOSP3P53322' 'HOSP6P02594' 'HOSP6P00515'
#  'HOSP4P116029' 'HOSP6P19599' 'HOSP6P01598' 'HOSP3P102413' 'HOSP4P107747'
#  'HOSP2P00774' 'HOSP6G07185' 'HOSP6P07624' 'HOSP3P57855' 'HOSP3P90400'
#  'HOSP6P00938' 'HOSP3P107059' 'HOSP3P101848' 'HOSP3P107614' 'HOSP3P106638'
#  'HOSP3P60900' 'HOSP3P111412' 'HOSP3P111175' 'HOSP3P111527' 'HOSP6P03828'
#  'HOSP6P03064' 'HOSP4P102289' 'HOSP6P03292' 'HOSP3P41900' 'HOSP3P11935'
#  'HOSP3P100422' 'HOSP3P100984' 'HOSP6P04942' 'HOSP6G03738' 'HOSP9P111492'
#  'HOSP6P01217' 'HOSP3P29227' 'HOSP3P65981' 'HOSP6P00939' 'HOSP1P55897'
#  'HOSP3P23279' 'HOSP6P03034' 'HOSP3P19649' 'HOSP6P02122' 'HOSP6P09739'
#  'HOSP3P46495' 'HOSP6P02433' 'HOSP3P113157' 'HOSP6P25023' 'HOSP3P52893'
#  'HOSP9G05874' 'HOSP6P03635' 'HOSP3P26972' 'HOSP3P10939' 'HOSP1P60054'
#  'HOSP6P03950' 'HOSP6P01471' 'HOSP6P16674' 'HOSP3P11119' 'HOSP5P02722'
#  'HOSP99P77967' 'HOSP6P02242' 'HOSP6P11436' 'HOSP6P03644' 'HOSP6P01964'
#  'HOSP6P02923' 'HOSP3P61863' 'HOSP5P00681' 'HOSP3P69762' 'HOSP23P03715'
#  'HOSP3P111415' 'HOSP3P100036' 'HOSP1G10281' 'HOSP6P00704' 'HOSP6P02906'
#  'HOSP3P99153' 'HOSP6P02968' 'HOSP3P93521' 'HOSP6P01925' 'HOSP3P101514'
#  'HOSP3P28806' 'HOSP1G22484' 'HOSP3P99510' 'HOSP6P01772' 'HOSP3P71363'
#  'HS02002085P' 'HOSP3P18678' 'HOSP24G11534' 'HOSP2P92329' 'HOSP3P107392'
#  'HOSP3P41761' 'HOSP6G03426' 'HOSP6P00560' 'HOSP6G03691' 'HOSP3P101974'
#  'HOSP6P86730' 'HOSP1G22904' 'HOSP37G19512' 'HOSP4P29822' 'HOSP6P02652'
#  'HOSP6P04185' 'HOSP6P05356' 'HOSP6P00706' 'HOSP6P03097' 'HOSP3P59251'
#  'HS02011033S' 'HOSP3P55492' 'HOSP6P02982' 'HOSP6P01940' 'HOSP6P92417'
#  'HOSP37G28616']
# Medical Service Provider Type : ['Hospital']
# Room Type : ['General Ward / ICU']
# Primary Diagnosis Code : ['S1' 'U1' 'M1' 'S4' 'S7' 'S5' 'M2' 'S3' 'M8' 'M3' 'S2' 'M7' 'MO' 'S8'
#  'M5' 'M6' 'SG' 'S6' 'S9' 'MG' '-N' 'SB' 'SL' 'MP' 'M4' 'SN' 'MC' 'SE'
#  'MM' 'SV' 'MR' 'SC' 'ST' 'SO']
# Primary Procedure Code : ['S100154' 'S1100001' 'S100020' ... 'S1400016' 'SG087A' 'M400028']
# Hospital Type : ['Public' 'Private']
# Type of Public Hospital : [nan 'CHC' 'Civil Hospital' 'SDH' 'DH' 'Medical College' 'PHC']
# TPA NAME : ['FHPL' 'Vidal']
# Benefit Code : ['SURGICAL' 'MEDICAL']
# Annual Client Premium Amount : ['597/Family']
# Gender Code : ['Female' 'Male']
# Residence Location : ['PATIALA' 'SANGRUR' 'FATEHGARH SAHIB' 'AMRITSAR' 'SRI MUKTSAR SAHIB'
#  'LUDHIANA' 'RUPNAGAR' 'FIROZEPUR' 'GURDASPUR' 'MOGA' 'BARNALA'
#  'PATHANKOT' 'Tarn Taran' 'KAPURTHALA' 'FARIDKOT' 'FAZILKA' 'HOSHIARPUR'
#  'BATHINDA' 'JALANDHAR' 'Shahid Bhagat Singh Nagar' 'S.A.S Nagar' 'MANSA']

# %% [markdown]
# ### Removing features with less no of unique values

# %%
remove_features_less_unique = ['Medical Service Provider Type', 'Room Type', 'Annual Client Premium Amount']

# %%
cleaned_df_1 = cleaned_df.drop(remove_features_less_unique, axis=1)

# %%
sns.heatmap(cleaned_df_1.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Split the data into X and y values

# %%
X_values = cleaned_df_1.iloc[:,:-1]
y_values = cleaned_df_1.iloc[:,-1]

# %% [markdown]
# ### Drop columns with similar features

# %%
X_values.drop('Insured Original Commencement Date',inplace = True, axis = 1) # policy commencement same as insured commencement
X_values.drop('Insured Effective Date',inplace = True, axis = 1) # policy effective same as insured effective
X_values.drop('Insured Termination Date',inplace = True, axis = 1) # policy termination same as insured termination
X_values.drop('Policy Effective Date',inplace = True, axis = 1) # policy effictive same as commencement
X_values.drop('Claim Paid Date',inplace = True, axis = 1) # paid date same as settlement date

# %% [markdown]
# ### Feature engineering

# %%
X_values['settlement_delay'] = X_values['Claim Settlement Date'] - X_values['Claim Reported Date']
X_values['settlement_delay'] = pd.to_numeric(X_values['settlement_delay'].dt.days, downcast='integer')
X_values['age']=(X_values['Claim Reported Date']-X_values['Birth Date ']).astype('<m8[Y]')
#X_values['dayoftheweekreported'] = X_values['Claim Reported Date'].dt.dayofweek

# %%
# Save the file
X_values.to_csv(r"./Data/Pre_Processed.csv", index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %%
X_values.isnull().sum()
# Out:
# Benefit Type                             0
# Claim Status                             0
# Treatment Start Date                     0
# Treatment End Date                   30254
# Claim Settlement Date                40986
# Claim Reported Date                  31941
# Claim Billed Amount                      0
# Approved / Allowed Amount                0
# Claim Paid Amount                    57552
# ClaimEvent_TPA_ID                        0
# Payment Tariff*                       1434
# Medical Service Provider ID              0
# No of Days Stayed                    30254
# Primary Diagnosis Code                   0
# Primary Procedure Code                 776
# Hospital Type                            0
# Type of Public Hospital             227136
# TPA NAME                                 0
# Net Amt                                  0
# Benefit Code                             0
# Policy Commencement Date                 0
# Policy Termination Date                  0
# Birth Date                               0
# Gender Code                              0
# Residence Location                       0
# Reject status more than 3 months         0
# settlement_delay                     41010
# age                                  31941
# dtype: int64

# %% [markdown]
# ### Draw histogram

# %%
X_values.hist(figsize=(20, 20));

# %% [markdown]
# ### Correlation matrix

# %%
corr = X_values.corr()
fit = plt.figure(figsize=(12, 9))
sns.heatmap(corr, square=True, annot=True, fmt=".1f" );

# %% [markdown]
# ### Create data with classes

# %%
EDA_data = X_values
EDA_data['Class'] = y_values

# %% [markdown]
# ### Correlation with classes

# %%
EDA_data.corrwith(EDA_data['Class']).plot.bar(
        figsize = (20, 10), title = "Correlation with class", grid = True)
# Out:
# <AxesSubplot:title={'center':'Correlation with class'}>

# %%
# Compute the correlation matrix
corr = EDA_data.corr()
fit = plt.figure(figsize=(12, 9))
sns.heatmap(corr, square=True, annot=True, fmt=".2f" );

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
s = sns.boxplot(ax = ax1, x="Class", y="Net Amt", hue="Class",data=EDA_data, palette="PRGn",showfliers=True)
s = sns.boxplot(ax = ax2, x="Class", y="Net Amt", hue="Class",data=EDA_data, palette="PRGn",showfliers=False)
plt.show();

# %% [markdown]
# ### Feature density plot

# %%
var = EDA_data.select_dtypes(exclude=['object_']).columns.values

i = 0
t0 = EDA_data.loc[EDA_data['Class'] == 0]
t1 = EDA_data.loc[EDA_data['Class'] == 1]

sns.set_style('whitegrid')
plt.figure()
fig, ax = plt.subplots(5,3,figsize=(16,28))

for feature in var:
    i += 1
    plt.subplot(6,3,i)
    sns.kdeplot(t0[feature], label="Class = 0")
    sns.kdeplot(t1[feature], label="Class = 1")
    plt.xlabel(feature, fontsize=12)
    locs, labels = plt.xticks()
    plt.tick_params(axis='both', which='major', labelsize=12)
plt.show();
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Owner\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Remove features that are correlated

# %%
drop_columns = ['Birth Date ', 'Claim Billed Amount', 'Approved / Allowed Amount', 'Claim Paid Amount', 'Payment Tariff*',
                'Type of Public Hospital', 'Treatment End Date', 'Primary Procedure Code', 'Claim Settlement Date']
EDA_data_cleaned = EDA_data.drop(drop_columns, axis=1)

# %%
# Compute the correlation matrix
corr = EDA_data_cleaned.drop('Class', axis=1).corr()
fit = plt.figure(figsize=(12, 9))
sns.heatmap(corr, square=True, annot=True, fmt=".2f" );

# %%
for features in EDA_data_cleaned.select_dtypes(include = 'object').columns:
    print(features, ":", EDA_data_cleaned[features].unique())
# Out:
# Benefit Type : ['SURGICAL' 'MEDICAL']
# Claim Status : ['Paid' 'Cancelled / Rejected' 'Outstanding' 'Pre-Auth Approved']
# Medical Service Provider ID : ['HOSP3G91629' 'HOSP3G59002' 'HOSP3G81429' 'HOSP3G82225' 'HOSP3G92566'
#  'HOSP3G81922' 'HOSP3G58357' 'HOSP3G81425' 'HOSP3P11538' 'HOSP3G81396'
#  'HOSP3P53909' 'HOSP3G80786' 'HOSP3P91871' 'HOSP3G83301' 'HOSP3G99957'
#  'HOSP3G58889' 'HOSP3G59094' 'HOSP3G81037' 'HOSP3G84341' 'HOSP3G80815'
#  'HOSP37G26966' 'HOSP3P11504' 'HOSP3P15999' 'HOSP3G81950' 'HOSP3P58295'
#  'HOSP3G61862' 'HOSP3G82867' 'HOSP3G82001' 'HOSP4G15575' 'HOSP3G84209'
#  'HOSP3P68104' 'HOSP3P57234' 'HOSP3P21150' 'HOSP3P28996' 'HOSP3G62650'
#  'HOSP3G100093' 'HOSP3G59614' 'HOSP3P49877' 'HOSP3G81952' 'HOSP3P71432'
#  'HOSP3G81176' 'HOSP3P62840' 'HOSP3P10675' 'HOSP3P25897' 'HOSP3G81939'
#  'HOSP3P57665' 'HOSP3G81096' 'HOSP3P23204' 'HOSP3P14339' 'HOSP3P59413'
#  'HOSP3G61363' 'HOSP3G80804' 'HOSP3P102602' 'HOSP3G81986' 'HOSP3G80774'
#  'HOSP3P68582' 'HOSP3G81094' 'HOSP3G81642' 'HOSP3P22560' 'HOSP3G93109'
#  'HOSP3G81062' 'HOSP3G84584' 'HOSP3P12267' 'HOSP3P89903' 'HOSP3P63305'
#  'HOSP3P13790' 'HOSP3P16686' 'HOSP3G81997' 'HOSP3P58002' 'HOSP3G81685'
#  'HOSP3P25606' 'HOSP3G84572' 'HOSP3P100609' 'HOSP3G81699' 'HOSP3P16665'
#  'HOSP3G60198' 'HOSP3G58366' 'HOSP3P11108' 'HOSP3P89941' 'HOSP3G81141'
#  'HOSP3P10731' 'HOSP3P21135' 'HOSP3P13265' 'HOSP3P11084' 'HOSP3P71794'
#  'HOSP3P58722' 'HOSP3P98542' 'HOSP3P12536' 'HOSP3P11828' 'HOSP3G81054'
#  'HOSP3P58556' 'HOSP3G81895' 'HOSP3P89205' 'HOSP3G81586' 'HOSP3P31431'
#  'HOSP3G82905' 'HOSP3G81606' 'HOSP3P60761' 'HOSP3G81458' 'HOSP3P57139'
#  'HOSP3P62634' 'HOSP3P14817' 'HOSP3P92088' 'HOSP3P70073' 'HOSP3P65443'
#  'HOSP3P68727' 'HOSP3G98484' 'HOSP3G80765' 'HOSP3G81345' 'HOSP3P20731'
#  'HOSP3P52841' 'HOSP3P54306' 'HOSP3G85223' 'HOSP3P10867' 'HOSP3G81849'
#  'HOSP3P25377' 'HOSP3P37440' 'HOSP3P58289' 'HOSP3P73510' 'HOSP3P66289'
#  'HOSP3P91932' 'HOSP3P15374' 'HOSP3P89888' 'HOSP3P32581' 'HOSP3G81110'
#  'HOSP3P61412' 'HOSP3P57777' 'HOSP3P15615' 'HOSP3P98975' 'HOSP3P106455'
#  'HOSP3P27593' 'HOSP3P70163' 'HOSP3G81130' 'HOSP3G84626' 'HOSP3P36957'
#  'HOSP3P93997' 'HOSP3P63055' 'HOSP3G81353' 'HOSP3G81976' 'HOSP3P98841'
#  'HOSP3P25184' 'HOSP3P92207' 'HOSP3P100531' 'HOSP3G90204' 'HOSP3G81908'
#  'HOSP3P66980' 'HOSP3G61100' 'HOSP3G81433' 'HOSP3P23154' 'HOSP3G99195'
#  'HOSP3G81150' 'HOSP3P59631' 'HOSP3P50519' 'HOSP3G78642' 'HOSP3G81120'
#  'HOSP3G81906' 'HOSP3P91089' 'HOSP3G81598' 'HOSP3G81180' 'HOSP3G58364'
#  'HOSP3G81369' 'HOSP3G58882' 'HOSP3P89415' 'HOSP3P66049' 'HOSP3P12798'
#  'HOSP3P19632' 'HOSP3P62546' 'HOSP3P93201' 'HOSP3P69756' 'HOSP3G88867'
#  'HOSP3P58829' 'HOSP3P56191' 'HOSP3P89895' 'HOSP3P70154' 'HOSP3P71424'
#  'HOSP3G86505' 'HOSP3P34001' 'HOSP3P57751' 'HOSP3G85691' 'HOSP3P13791'
#  'HOSP3P21239' 'HOSP3P60563' 'HOSP3P58422' 'HOSP3P12041' 'HOSP3P19707'
#  'HOSP3P19700' 'HOSP3P93614' 'HOSP3G63048' 'HOSP3G80779' 'HOSP3P89959'
#  'HOSP3P99164' 'HOSP3G84574' 'HOSP3G81158' 'HOSP3G77043' 'HOSP3P61881'
#  'HOSP3G81632' 'HOSP3P69760' 'HOSP3P100035' 'HOSP3P38200' 'HOSP3P63299'
#  'HOSP3P92120' 'HOSP3P16183' 'HOSP3G81059' 'HOSP3P98811' 'HOSP3P102822'
#  'HOSP3P11450' 'HOSP3P23124' 'HOSP3G81360' 'HOSP3P89406' 'HOSP3G91686'
#  'HOSP3G58245' 'HOSP3G58377' 'HOSP3G58475' 'HOSP3G81376' 'HOSP3P25404'
#  'HOSP3P16365' 'HOSP3G91709' 'HOSP3G90904' 'HOSP3P22961' 'HOSP3G81644'
#  'HOSP3P24067' 'HOSP3P58568' 'HOSP3P30412' 'HOSP3P81352' 'HOSP3G81040'
#  'HOSP3G81070' 'HOSP3G81078' 'HOSP3G80800' 'HOSP3P63429' 'HOSP3G81672'
#  'HOSP3G81134' 'HOSP3G80773' 'HOSP3G81679' 'HOSP3P59028' 'HOSP3P111573'
#  'HOSP3G82019' 'HOSP3G80824' 'HOSP3G81619' 'HOSP3P102615' 'HOSP3P70074'
#  'HOSP3G62462' 'HOSP3G89881' 'HOSP3G81961' 'HOSP3G89889' 'HOSP3P99900'
#  'HOSP3G81637' 'HOSP3P65603' 'HOSP3G81367' 'HOSP3G81924' 'HOSP3G91678'
#  'HOSP3P22830' 'HOSP3P11274' 'HOSP3G60508' 'HOSP3P74532' 'HOSP3G81097'
#  'HOSP3P65756' 'HOSP3G81413' 'HOSP3P70449' 'HOSP3G81942' 'HOSP3P103041'
#  'HOSP3G84598' 'HOSP3G63378' 'HOSP3P16302' 'HOSP3P59194' 'HOSP3G73378'
#  'HOSP3P57316' 'HOSP3P58486' 'HOSP3G98957' 'HOSP3G83067' 'HOSP3P53030'
#  'HOSP3G81649' 'HOSP3G80838' 'HOSP3G81690' 'HOSP3G58215' 'HOSP3P11665'
#  'HOSP3G74692' 'HOSP3P57094' 'HOSP3G85209' 'HOSP3P23149' 'HOSP3P25397'
#  'HOSP3P10674' 'HOSP3G81636' 'HOSP3P62736' 'HOSP3P10941' 'HOSP3P32871'
#  'HOSP3G83458' 'HOSP3P52368' 'HOSP3P102190' 'HOSP3P58222' 'HOSP3P43363'
#  'HOSP3P89898' 'HOSP3P10931' 'HOSP3G81090' 'HOSP6P01175' 'HOSP3G81061'
#  'HOSP3G81119' 'HOSP3G81085' 'HOSP3P106633' 'HOSP3P91173' 'HOSP3G91723'
#  'HOSP3P67729' 'HOSP3P48986' 'HOSP3P19873' 'HOSP3P62601' 'HOSP3P16493'
#  'HOSP3G81609' 'HOSP3P51816' 'HOSP3P11844' 'HOSP3G81350' 'HOSP3G100273'
#  'HOSP3G81941' 'HOSP3P12139' 'HOSP3G107097' 'HOSP3P37094' 'HOSP3G80780'
#  'HOSP3G81058' 'HOSP3P15544' 'HOSP3P36649' 'HOSP3G62418' 'HOSP3G62421'
#  'HOSP3P59683' 'HOSP3G81669' 'HOSP3G81931' 'HOSP3P26108' 'HOSP3G78848'
#  'HOSP3P34245' 'HOSP3P29987' 'HOSP3G81984' 'HOSP3G83264' 'HOSP3G58371'
#  'HOSP3P51801' 'HOSP3G81416' 'HOSP3P63332' 'HOSP3P70927' 'HOSP6P01558'
#  'HOSP3G81129' 'HOSP3P18661' 'HOSP3P101302' 'HOSP3P58849' 'HOSP3P90752'
#  'HOSP3G81894' 'HOSP3G82195' 'HOSP3G58365' 'HOSP3P85673' 'HOSP3P11092'
#  'HOSP3P85280' 'HOSP3P63880' 'HOSP3G82866' 'HOSP3P19597' 'HOSP3P91583'
#  'HOSP3P34433' 'HOSP3G81958' 'HOSP3P11877' 'HOSP3P41653' 'HOSP3P68803'
#  'HOSP3P72345' 'HOSP3P60261' 'HOSP3P13813' 'HOSP3P61660' 'HOSP3P10926'
#  'HOSP3P50173' 'HOSP3G61164' 'HOSP3G82002' 'HOSP3P85453' 'HOSP3P59586'
#  'HOSP3G99794' 'HOSP3P37308' 'HOSP3P60565' 'HOSP3G81994' 'HOSP3G81092'
#  'HOSP6P01945' 'HOSP3G62599' 'HOSP3P93605' 'HOSP3P57220' 'HOSP3P90917'
#  'HOSP3P14357' 'HOSP3G81391' 'HOSP3G81683' 'HOSP4P62024' 'HOSP4G03896'
#  'HOSP3P11484' 'HOSP3P21606' 'HOSP3G81660' 'HOSP3P39371' 'HOSP3G91688'
#  'HOSP3G88411' 'HOSP3G81064' 'HOSP3G91564' 'HOSP3P11982' 'HOSP3G91691'
#  'HOSP3P29128' 'HOSP3P59050' 'HOSP3P37939' 'HOSP3P11105' 'HOSP3P91735'
#  'HOSP3P57602' 'HOSP3G91626' 'HOSP3G58356' 'HOSP3P81794' 'HOSP3P11387'
#  'HOSP3P58209' 'HOSP3P100707' 'HOSP3P100834' 'HOSP3P92697' 'HOSP3P27540'
#  'HOSP3P58777' 'HOSP3P28713' 'HOSP3P69789' 'HOSP3P70103' 'HOSP3P26340'
#  'HOSP3P13748' 'HOSP3G81178' 'HOSP3P20997' 'HOSP3P58268' 'HOSP3P101114'
#  'HOSP3P57667' 'HOSP3P60234' 'HOSP3P49016' 'HOSP4P81206' 'HOSP3G91710'
#  'HOSP3P100284' 'HOSP3P78495' 'HOSP3P44541' 'HOSP3P11377' 'HOSP3P37874'
#  'HOSP3P113832' 'HOSP4P04814' 'HOSP3P16060' 'HOSP3G82010' 'HOSP3P60227'
#  'HOSP3P101167' 'HOSP3P21127' 'HOSP3P100611' 'HOSP3P73589' 'HOSP3P102425'
#  'HOSP3P34643' 'HOSP3P11001' 'HOSP6G03704' 'HOSP3G82654' 'HOSP3P56551'
#  'HOSP3P98739' 'HOSP3G81946' 'HOSP3P63281' 'HOSP3P111578' 'HOSP3P111036'
#  'HOSP3P66542' 'HOSP3P24411' 'HOSP3G81617' 'HOSP3P110976' 'HOSP3P23214'
#  'HOSP3P100997' 'HOSP3P50316' 'HOSP3P21928' 'HOSP3P102242' 'HOSP3P10932'
#  'HOSP3P91585' 'HOSP3P58639' 'HOSP3P101054' 'HOSP3P111544' 'HOSP3P34957'
#  'HOSP3P20747' 'HOSP3P23321' 'HOSP3P10934' 'HOSP3P42898' 'HOSP3P19656'
#  'HOSP3G81707' 'HOSP3G108546' 'HOSP3P27677' 'HOSP3P51656' 'HOSP3G110981'
#  'HOSP3P13343' 'HOSP3P50507' 'HOSP3G98509' 'HOSP3G81105' 'HOSP3P59662'
#  'HOSP3P84011' 'HOSP3P59930' 'HOSP3P92625' 'HOSP3P98839' 'HOSP3P65870'
#  'HOSP3P58279' 'HOSP6P02251' 'HOSP3P21232' 'HOSP3P70087' 'HOSP3P27412'
#  'HOSP3P46490' 'HOSP3P22347' 'HOSP3P86179' 'HOSP3P100854' 'HOSP3G102321'
#  'HOSP3P101287' 'HOSP3P36398' 'HOSP3P82682' 'HOSP3P113382' 'HOSP3P91673'
#  'HOSP3P107658' 'HOSP3P65872' 'HOSP3G81086' 'HOSP3G81124' 'HOSP3P101350'
#  'HOSP37G36989' 'HOSP3G83078' 'HOSP3P50725' 'HOSP6P98291' 'HOSP3G82024'
#  'HOSP3P83652' 'HOSP4G12390' 'HOSP3P23004' 'HOSP3P12074' 'HOSP3P16177'
#  'HOSP3P10737' 'HOSP3P57208' 'HOSP4P91096' 'HOSP3P62852' 'HOSP3P100485'
#  'HOSP3P102483' 'HOSP3G60105' 'HOSP3G58990' 'HOSP3P59889' 'HOSP3P47862'
#  'HOSP3P83166' 'HOSP3P90933' 'HOSP3P91921' 'HOSP3P68259' 'HOSP3G80862'
#  'HOSP3G60007' 'HOSP3P23501' 'HOSP3G81126' 'HOSP3G81956' 'HOSP3G81144'
#  'HOSP3G90126' 'HOSP3P40661' 'HOSP3P23392' 'HOSP3G91599' 'HOSP3P111247'
#  'HOSP3P46552' 'HOSP3P103100' 'HOSP3P60163' 'HOSP3P57133' 'HOSP3P11241'
#  'HOSP3P93572' 'HOSP3P34388' 'HOSP3P86790' 'HOSP3G81056' 'HOSP3P102667'
#  'HOSP3G81137' 'HOSP3P24138' 'HOSP4P03549' 'HOSP3P72312' 'HOSP3P62720'
#  'HOSP3P93295' 'HOSP3P102568' 'HOSP3P88439' 'HOSP3P12199' 'HOSP3P59485'
#  'HOSP3G81959' 'HOSP3P62730' 'HOSP3P81402' 'HOSP3P68963' 'HOSP3P61911'
#  'HOSP3P58515' 'HOSP3P48163' 'HOSP3G108371' 'HOSP3P111110' 'HOSP2P36382'
#  'HOSP3P101018' 'HOSP3P23106' 'HOSP3P93446' 'HOSP3P101064' 'HOSP3G80819'
#  'HOSP3P61214' 'HOSP3P91158' 'HOSP3P21345' 'HOSP3P117383' 'HOSP3P61691'
#  'HOSP6G03078' 'HOSP3P101005' 'HOSP3P81853' 'HOSP3P11535' 'HOSP3P92559'
#  'HOSP27P79085' 'HOSP3P90355' 'HOSP3P91023' 'HOSP3P52198' 'HOSP3P60005'
#  'HOSP3P23162' 'HOSP3P89146' 'HOSP3P10943' 'HOSP3P41116' 'HOSP3G113581'
#  'HOSP3P91483' 'HOSP3P91248' 'HOSP6G03077' 'HOSP3P13794' 'HOSP3P38106'
#  'HOSP3P89499' 'HOSP3P60222' 'HOSP3P41475' 'HOSP3P78786' 'HOSP3P106329'
#  'HOSP3P12330' 'HOSP3P92246' 'HOSP3P99146' 'HOSP3P11702' 'HOSP3P43077'
#  'HOSP3P56458' 'HOSP3P57856' 'HOSP3P10697' 'HOSP3P98324' 'HOSP3G58220'
#  'HOSP3P12304' 'HOSP3P21005' 'HOSP3P13707' 'HOSP3P58199' 'HOSP3P93065'
#  'HOSP4G13746' 'HOSP3P11807' 'HOSP3P11361' 'HOSP6P05568' 'HOSP3P27055'
#  'HOSP3P98523' 'HOSP3P104181' 'HOSP3P38356' 'HOSP3P107465' 'HOSP3P102003'
#  'HOSP3P61114' 'HOSP3P103147' 'HOSP3P84050' 'HOSP3P113022' 'HOSP3P67589'
#  'HOSP3P102519' 'HOSP3P60528' 'HOSP3P90638' 'HOSP3P24079' 'HOSP23P01386'
#  'HOSP3P98838' 'HOSP3P89977' 'HOSP3P90935' 'HOSP3P99374' 'HS02002070P'
#  'HOSP6P01453' 'HOSP3P111714' 'HOSP3P57787' 'HOSP3P65538' 'HOSP5G07688'
#  'HOSP3P42945' 'HOSP3P90278' 'HOSP6G03026' 'HOSP3P12846' 'HOSP3P90522'
#  'HOSP3G83255' 'HOSP27P79289' 'HOSP3P62109' 'HOSP6P02148' 'HOSP3P99055'
#  'HOSP23P78856' 'HOSP6P01428' 'HOSP3P35652' 'HOSP6P01584' 'HOSP1G22894'
#  'HOSP3P44812' 'HOSP3P23988' 'HOSP3P92621' 'HOSP3P15671' 'HOSP3P22294'
#  'HOSP3P106258' 'HOSP6P00642' 'HOSP3P100873' 'HOSP3P91301' 'HOSP3P22987'
#  'HOSP3P65844' 'HOSP3P100807' 'HOSP3P11652' 'HOSP9P02385' 'HOSP3P108630'
#  'HOSP3P95437' 'HOSP3P106341' 'HOSP3P60610' 'HOSP6P31021' 'HOSP3P32843'
#  'HOSP3P24169' 'HOSP3P101103' 'HOSP3P108307' 'HS02002048P' 'HOSP37G36554'
#  'HOSP3P41104' 'HOSP4P89965' 'HOSP6P00618' 'HOSP3P46255' 'HOSP6P02346'
#  'HOSP3P39259' 'HOSP3P92416' 'HOSP6P02014' 'HOSP3P111577' 'HOSP3P15270'
#  'HOSP2P89570' 'HOSP3P101319' 'HOSP4P15654' 'HOSP4G14359' 'HOSP6P03100'
#  'HOSP3P57633' 'HOSP3P15399' 'HOSP3P102900' 'HOSP6G03056' 'HOSP3P108941'
#  'HOSP3P10680' 'HOSP6P02104' 'HOSP6P02402' 'HOSP6P02165' 'HOSP3P11923'
#  'HOSP3G106260' 'HOSP6P01989' 'HS02009034P' 'HOSP37G31478' 'HOSP3P88864'
#  'HOSP3P60092' 'HOSP3P66606' 'HOSP3P53322' 'HOSP6P02594' 'HOSP6P00515'
#  'HOSP4P116029' 'HOSP6P19599' 'HOSP6P01598' 'HOSP3P102413' 'HOSP4P107747'
#  'HOSP2P00774' 'HOSP6G07185' 'HOSP6P07624' 'HOSP3P57855' 'HOSP3P90400'
#  'HOSP6P00938' 'HOSP3P107059' 'HOSP3P101848' 'HOSP3P107614' 'HOSP3P106638'
#  'HOSP3P60900' 'HOSP3P111412' 'HOSP3P111175' 'HOSP3P111527' 'HOSP6P03828'
#  'HOSP6P03064' 'HOSP4P102289' 'HOSP6P03292' 'HOSP3P41900' 'HOSP3P11935'
#  'HOSP3P100422' 'HOSP3P100984' 'HOSP6P04942' 'HOSP6G03738' 'HOSP9P111492'
#  'HOSP6P01217' 'HOSP3P29227' 'HOSP3P65981' 'HOSP6P00939' 'HOSP1P55897'
#  'HOSP3P23279' 'HOSP6P03034' 'HOSP3P19649' 'HOSP6P02122' 'HOSP6P09739'
#  'HOSP3P46495' 'HOSP6P02433' 'HOSP3P113157' 'HOSP6P25023' 'HOSP3P52893'
#  'HOSP9G05874' 'HOSP6P03635' 'HOSP3P26972' 'HOSP3P10939' 'HOSP1P60054'
#  'HOSP6P03950' 'HOSP6P01471' 'HOSP6P16674' 'HOSP3P11119' 'HOSP5P02722'
#  'HOSP99P77967' 'HOSP6P02242' 'HOSP6P11436' 'HOSP6P03644' 'HOSP6P01964'
#  'HOSP6P02923' 'HOSP3P61863' 'HOSP5P00681' 'HOSP3P69762' 'HOSP23P03715'
#  'HOSP3P111415' 'HOSP3P100036' 'HOSP1G10281' 'HOSP6P00704' 'HOSP6P02906'
#  'HOSP3P99153' 'HOSP6P02968' 'HOSP3P93521' 'HOSP6P01925' 'HOSP3P101514'
#  'HOSP3P28806' 'HOSP1G22484' 'HOSP3P99510' 'HOSP6P01772' 'HOSP3P71363'
#  'HS02002085P' 'HOSP3P18678' 'HOSP24G11534' 'HOSP2P92329' 'HOSP3P107392'
#  'HOSP3P41761' 'HOSP6G03426' 'HOSP6P00560' 'HOSP6G03691' 'HOSP3P101974'
#  'HOSP6P86730' 'HOSP1G22904' 'HOSP37G19512' 'HOSP4P29822' 'HOSP6P02652'
#  'HOSP6P04185' 'HOSP6P05356' 'HOSP6P00706' 'HOSP6P03097' 'HOSP3P59251'
#  'HS02011033S' 'HOSP3P55492' 'HOSP6P02982' 'HOSP6P01940' 'HOSP6P92417'
#  'HOSP37G28616']
# Primary Diagnosis Code : ['S1' 'U1' 'M1' 'S4' 'S7' 'S5' 'M2' 'S3' 'M8' 'M3' 'S2' 'M7' 'MO' 'S8'
#  'M5' 'M6' 'SG' 'S6' 'S9' 'MG' '-N' 'SB' 'SL' 'MP' 'M4' 'SN' 'MC' 'SE'
#  'MM' 'SV' 'MR' 'SC' 'ST' 'SO']
# Hospital Type : ['Public' 'Private']
# TPA NAME : ['FHPL' 'Vidal']
# Benefit Code : ['SURGICAL' 'MEDICAL']
# Gender Code : ['Female' 'Male']
# Residence Location : ['PATIALA' 'SANGRUR' 'FATEHGARH SAHIB' 'AMRITSAR' 'SRI MUKTSAR SAHIB'
#  'LUDHIANA' 'RUPNAGAR' 'FIROZEPUR' 'GURDASPUR' 'MOGA' 'BARNALA'
#  'PATHANKOT' 'Tarn Taran' 'KAPURTHALA' 'FARIDKOT' 'FAZILKA' 'HOSHIARPUR'
#  'BATHINDA' 'JALANDHAR' 'Shahid Bhagat Singh Nagar' 'S.A.S Nagar' 'MANSA']

# %% [markdown]
# ### Fill missing values

# %%
median1 = EDA_data_cleaned['No of Days Stayed'].median()
print(median1)
EDA_data_cleaned['No of Days Stayed'].replace(np.nan,median1,inplace = True)
# Out:
# 3.0

# %%
mean1 = int(EDA_data_cleaned['settlement_delay'].mean())
print(mean1)
# Out:
# 17

# %%
EDA_data_cleaned['settlement_delay'].replace(np.nan,mean1,inplace = True)

# %%
categorical_feature = ['Reject status more than 3 months', 'ClaimEvent_TPA_ID']

# %%
mean2 = int(EDA_data_cleaned['age'].mean())
print(mean2)
# Out:
# 49

# %%
EDA_data_cleaned['age'].replace(np.nan,mean2,inplace = True)

# %%
EDA_data_cleaned.isnull().sum()
# Out:
# Benefit Type                            0
# Claim Status                            0
# Treatment Start Date                    0
# Claim Reported Date                 31941
# ClaimEvent_TPA_ID                       0
# Medical Service Provider ID             0
# No of Days Stayed                       0
# Primary Diagnosis Code                  0
# Hospital Type                           0
# TPA NAME                                0
# Net Amt                                 0
# Benefit Code                            0
# Policy Commencement Date                0
# Policy Termination Date                 0
# Gender Code                             0
# Residence Location                      0
# Reject status more than 3 months        0
# settlement_delay                        0
# age                                     0
# Class                                   0
# dtype: int64

# %%
EDA_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382587 entries, 0 to 382586
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Benefit Type                      382587 non-null  object
#  1   Claim Status                      382587 non-null  object
#  2   Treatment Start Date              382587 non-null  datetime64[ns]
#  3   Claim Reported Date               350646 non-null  datetime64[ns]
#  4   ClaimEvent_TPA_ID                 382587 non-null  int64
#  5   Medical Service Provider ID       382587 non-null  object
#  6   No of Days Stayed                 382587 non-null  float64
#  7   Primary Diagnosis Code            382587 non-null  object
#  8   Hospital Type                     382587 non-null  object
#  9   TPA NAME                          382587 non-null  object
#  10  Net Amt                           382587 non-null  int64
#  11  Benefit Code                      382587 non-null  object
#  12  Policy Commencement Date          382587 non-null  datetime64[ns]
#  13  Policy Termination Date           382587 non-null  datetime64[ns]
#  14  Gender Code                       382587 non-null  object
#  15  Residence Location                382587 non-null  object
#  16  Reject status more than 3 months  382587 non-null  int64
#  17  settlement_delay                  382587 non-null  float64
#  18  age                               382587 non-null  float64
#  19  Class                             382587 non-null  int64
# dtypes: datetime64[ns](4), float64(3), int64(4), object(9)
# memory usage: 58.4+ MB

# %%
sns.heatmap(EDA_data_cleaned.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Filling missing data by random choosing from non missing values

# %%
EDA_data_cleaned['Claim Reported Date']
# Out:
# 0        2020-01-01 16:07:00
# 1        2020-06-17 09:13:00
# 2        2019-11-29 09:32:00
# 3        2020-06-27 08:47:00
# 4        2020-01-23 14:41:00
#                  ...
# 382582   2019-10-18 15:36:00
# 382583   2020-06-02 13:03:00
# 382584   2019-01-11 13:00:00
# 382585   2020-07-17 11:12:00
# 382586   2019-09-22 14:16:00
# Name: Claim Reported Date, Length: 382587, dtype: datetime64[ns]

# %%
EDA_data_cleaned['Claim Reported Date'].isnull().sum()
# Out:
# 31941

# %%
EDA_data_cleaned['Claim Reported Date'].fillna(random.choice(EDA_data_cleaned[EDA_data_cleaned['Claim Reported Date'] != np.nan]['Claim Reported Date']), inplace=True)

# %%
sns.heatmap(EDA_data_cleaned.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
EDA_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382587 entries, 0 to 382586
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Benefit Type                      382587 non-null  object
#  1   Claim Status                      382587 non-null  object
#  2   Treatment Start Date              382587 non-null  datetime64[ns]
#  3   Claim Reported Date               382587 non-null  datetime64[ns]
#  4   ClaimEvent_TPA_ID                 382587 non-null  int64
#  5   Medical Service Provider ID       382587 non-null  object
#  6   No of Days Stayed                 382587 non-null  float64
#  7   Primary Diagnosis Code            382587 non-null  object
#  8   Hospital Type                     382587 non-null  object
#  9   TPA NAME                          382587 non-null  object
#  10  Net Amt                           382587 non-null  int64
#  11  Benefit Code                      382587 non-null  object
#  12  Policy Commencement Date          382587 non-null  datetime64[ns]
#  13  Policy Termination Date           382587 non-null  datetime64[ns]
#  14  Gender Code                       382587 non-null  object
#  15  Residence Location                382587 non-null  object
#  16  Reject status more than 3 months  382587 non-null  int64
#  17  settlement_delay                  382587 non-null  float64
#  18  age                               382587 non-null  float64
#  19  Class                             382587 non-null  int64
# dtypes: datetime64[ns](4), float64(3), int64(4), object(9)
# memory usage: 58.4+ MB

# %%
EDA_data_cleaned['Start_year'] = EDA_data_cleaned['Treatment Start Date'].dt.year
EDA_data_cleaned['Start_month'] = EDA_data_cleaned['Treatment Start Date'].dt.month
EDA_data_cleaned['Start_week'] = EDA_data_cleaned['Treatment Start Date'].dt.week
EDA_data_cleaned['Start_day'] = EDA_data_cleaned['Treatment Start Date'].dt.day
EDA_data_cleaned['Start_dayofweek'] = EDA_data_cleaned['Treatment Start Date'].dt.dayofweek

EDA_data_cleaned['Reported_year'] = EDA_data_cleaned['Claim Reported Date'].dt.year
EDA_data_cleaned['Reported_month'] = EDA_data_cleaned['Claim Reported Date'].dt.month
EDA_data_cleaned['Reported_week'] = EDA_data_cleaned['Claim Reported Date'].dt.week
EDA_data_cleaned['Reported_day'] = EDA_data_cleaned['Claim Reported Date'].dt.day
EDA_data_cleaned['Reported_dayofweek'] = EDA_data_cleaned['Claim Reported Date'].dt.dayofweek

EDA_data_cleaned['Commencement_year'] = EDA_data_cleaned['Policy Commencement Date'].dt.year
EDA_data_cleaned['Commencement_month'] = EDA_data_cleaned['Policy Commencement Date'].dt.month
EDA_data_cleaned['Commencement_week'] = EDA_data_cleaned['Policy Commencement Date'].dt.week
EDA_data_cleaned['Commencement_day'] = EDA_data_cleaned['Policy Commencement Date'].dt.day
EDA_data_cleaned['Commencement_dayofweek'] = EDA_data_cleaned['Policy Commencement Date'].dt.dayofweek

EDA_data_cleaned['Termination_year'] = EDA_data_cleaned['Policy Termination Date'].dt.year
EDA_data_cleaned['Termination_month'] = EDA_data_cleaned['Policy Termination Date'].dt.month
EDA_data_cleaned['Termination_week'] = EDA_data_cleaned['Policy Termination Date'].dt.week
EDA_data_cleaned['Termination_day'] = EDA_data_cleaned['Policy Termination Date'].dt.day
EDA_data_cleaned['Termination_dayofweek'] = EDA_data_cleaned['Policy Termination Date'].dt.dayofweek
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if __name__ == '__main__':
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   from ipykernel import kernelapp as app
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
drop_features = ['Treatment Start Date', 'Claim Reported Date', 'Policy Commencement Date', 'Policy Termination Date']
EDA_data_cleaned.drop(drop_features, axis=1, inplace=True)

# %%
EDA_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382587 entries, 0 to 382586
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Benefit Type                      382587 non-null  object
#  1   Claim Status                      382587 non-null  object
#  2   ClaimEvent_TPA_ID                 382587 non-null  int64
#  3   Medical Service Provider ID       382587 non-null  object
#  4   No of Days Stayed                 382587 non-null  float64
#  5   Primary Diagnosis Code            382587 non-null  object
#  6   Hospital Type                     382587 non-null  object
#  7   TPA NAME                          382587 non-null  object
#  8   Net Amt                           382587 non-null  int64
#  9   Benefit Code                      382587 non-null  object
#  10  Gender Code                       382587 non-null  object
#  11  Residence Location                382587 non-null  object
#  12  Reject status more than 3 months  382587 non-null  int64
#  13  settlement_delay                  382587 non-null  float64
#  14  age                               382587 non-null  float64
#  15  Class                             382587 non-null  int64
#  16  Start_year                        382587 non-null  int64
#  17  Start_month                       382587 non-null  int64
#  18  Start_week                        382587 non-null  int64
#  19  Start_day                         382587 non-null  int64
#  20  Start_dayofweek                   382587 non-null  int64
#  21  Reported_year                     382587 non-null  int64
#  22  Reported_month                    382587 non-null  int64
#  23  Reported_week                     382587 non-null  int64
#  24  Reported_day                      382587 non-null  int64
#  25  Reported_dayofweek                382587 non-null  int64
#  26  Commencement_year                 382587 non-null  int64
#  27  Commencement_month                382587 non-null  int64
#  28  Commencement_week                 382587 non-null  int64
#  29  Commencement_day                  382587 non-null  int64
#  30  Commencement_dayofweek            382587 non-null  int64
#  31  Termination_year                  382587 non-null  int64
#  32  Termination_month                 382587 non-null  int64
#  33  Termination_week                  382587 non-null  int64
#  34  Termination_day                   382587 non-null  int64
#  35  Termination_dayofweek             382587 non-null  int64
# dtypes: float64(3), int64(24), object(9)
# memory usage: 105.1+ MB

# %%
df1 = EDA_data_cleaned.pop('Class')

# %%
EDA_data_cleaned['Class'] =df1

# %%
EDA_data_cleaned['settlement_delay']=EDA_data_cleaned['settlement_delay'].astype('int64')
EDA_data_cleaned['age']=EDA_data_cleaned['age'].astype('int64')
EDA_data_cleaned['No of Days Stayed']=EDA_data_cleaned['No of Days Stayed'].astype('int64')
EDA_data_cleaned['ClaimEvent_TPA_ID']=EDA_data_cleaned['ClaimEvent_TPA_ID'].astype('object')
EDA_data_cleaned['Reject status more than 3 months']=EDA_data_cleaned['Reject status more than 3 months'].astype('object')
EDA_data_cleaned['Class']=EDA_data_cleaned['Class'].astype('object')

# %%
EDA_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382587 entries, 0 to 382586
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Benefit Type                      382587 non-null  object
#  1   Claim Status                      382587 non-null  object
#  2   ClaimEvent_TPA_ID                 382587 non-null  object
#  3   Medical Service Provider ID       382587 non-null  object
#  4   No of Days Stayed                 382587 non-null  int64
#  5   Primary Diagnosis Code            382587 non-null  object
#  6   Hospital Type                     382587 non-null  object
#  7   TPA NAME                          382587 non-null  object
#  8   Net Amt                           382587 non-null  int64
#  9   Benefit Code                      382587 non-null  object
#  10  Gender Code                       382587 non-null  object
#  11  Residence Location                382587 non-null  object
#  12  Reject status more than 3 months  382587 non-null  object
#  13  settlement_delay                  382587 non-null  int64
#  14  age                               382587 non-null  int64
#  15  Start_year                        382587 non-null  int64
#  16  Start_month                       382587 non-null  int64
#  17  Start_week                        382587 non-null  int64
#  18  Start_day                         382587 non-null  int64
#  19  Start_dayofweek                   382587 non-null  int64
#  20  Reported_year                     382587 non-null  int64
#  21  Reported_month                    382587 non-null  int64
#  22  Reported_week                     382587 non-null  int64
#  23  Reported_day                      382587 non-null  int64
#  24  Reported_dayofweek                382587 non-null  int64
#  25  Commencement_year                 382587 non-null  int64
#  26  Commencement_month                382587 non-null  int64
#  27  Commencement_week                 382587 non-null  int64
#  28  Commencement_day                  382587 non-null  int64
#  29  Commencement_dayofweek            382587 non-null  int64
#  30  Termination_year                  382587 non-null  int64
#  31  Termination_month                 382587 non-null  int64
#  32  Termination_week                  382587 non-null  int64
#  33  Termination_day                   382587 non-null  int64
#  34  Termination_dayofweek             382587 non-null  int64
#  35  Class                             382587 non-null  object
# dtypes: int64(24), object(12)
# memory usage: 105.1+ MB

# %%
EDA_data_cleaned.to_csv(r"./Data/Cleaned.csv", index=False)
